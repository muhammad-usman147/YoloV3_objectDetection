# %%
from google.colab import drive
drive.mount('/content/gdrive')
#to connect drive
# Out:
# Mounted at /content/gdrive

# %%
# !ls '/content/gdrive/MyDrive/asfar-yolo-custom-model'
# Out:
# custom_gun.zip	darknet  DATASET-ASFAR-gun-FRAME

# %%
# !unzip '/content/gdrive/MyDrive/asfar-yolo-custom-model/custom_gun.zip' -d '/content/gdrive/MyDrive/asfar-yolo-custom-model'
# Out:
# Archive:  /content/gdrive/MyDrive/asfar-yolo-custom-model/custom_gun.zip
# replace /content/gdrive/MyDrive/asfar-yolo-custom-model/DATASET-ASFAR-gun-FRAME/frame100.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename:

# %%
# !git clone https://github.com/pjreddie/darknet.git /content/gdrive/MyDrive/asfar-yolo-custom-model/darknet
# Out:
# fatal: destination path '/content/gdrive/MyDrive/asfar-yolo-custom-model/darknet' already exists and is not an empty directory.

# %%
# %cd /content/gdrive/MyDrive/asfar-yolo-custom-model/darknet
# Out:
# /content/gdrive/MyDrive/asfar-yolo-custom-model/darknet

# %%
# !ls
# Out:
# backup	 examples	LICENSE       LICENSE.meta  obj        scripts
# cfg	 include	LICENSE.fuck  LICENSE.mit   python     src
# darknet  libdarknet.a	LICENSE.gen   LICENSE.v1    README.md
# data	 libdarknet.so	LICENSE.gpl   Makefile	    results

# %%
# !make
# Out:
# gcc -Iinclude/ -Isrc/ -DOPENCV `pkg-config --cflags opencv`  -DGPU -I/usr/local/cuda/include/ -DCUDNN  -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -c ./src/gemm.c -o obj/gemm.o
# ./src/gemm.c: In function ‘time_gpu’:
# ./src/gemm.c:232:9: warning: ‘cudaThreadSynchronize’ is deprecated [-Wdeprecated-declarations]
#          cudaThreadSynchronize();
#          ^~~~~~~~~~~~~~~~~~~~~
# In file included from /usr/local/cuda/include/cuda_runtime.h:96:0,
#                  from include/darknet.h:11,
#                  from ./src/utils.h:5,
#                  from ./src/gemm.c:2:
# /usr/local/cuda/include/cuda_runtime_api.h:1004:57: note: declared here
#  extern __CUDA_DEPRECATED __host__ cudaError_t CUDARTAPI cudaThreadSynchronize(void);
#                                                          ^~~~~~~~~~~~~~~~~~~~~
# ...

# %%
# %cd /content/gdrive/MyDrive/asfar-yolo-custom-model
# Out:
# /content/gdrive/MyDrive/asfar-yolo-custom-model

# %%
# !ls
# Out:
# custom_gun.zip	darknet  DATASET-ASFAR-gun-FRAME

# %%
# !python DATASET-ASFAR-gun-FRAME/creating-files-data-and-name.py

# %%
# !python DATASET-ASFAR-gun-FRAME/creating-train-and-test-txt-files.py

# %%
import os
os.listdir('DATASET-ASFAR-gun-FRAME/')
# Out:
# ['frame1476.jpg',
#  'frame1444.jpg',
#  'frame1536.jpg',
#  'frame1156.jpg',
#  'frame1560.jpg',
#  'frame1640.jpg',
#  'frame1392.jpg',
#  'frame1252.jpg',
#  'frame1540.jpg',
#  'frame1440.jpg',
#  'frame1196.jpg',
#  'frame1152.jpg',
#  'frame1276.jpg',
#  'frame1200.jpg',
#  'frame1468.jpg',
#  'frame1328.jpg',
#  'frame1616.jpg',
#  'frame1148.jpg',
#  'frame1580.jpg',
#  'frame1680.jpg',
#  'frame1648.jpg',
#  'frame1172.jpg',
#  'frame1724.jpg',
#  'frame1348.jpg',
#  'frame1216.jpg',
#  'frame1692.jpg',
#  'frame1804.jpg',
#  'frame1376.jpg',
#  'frame1408.jpg',
#  'frame1228.jpg',
#  'frame1324.jpg',
#  'frame1516.jpg',
#  'frame1656.jpg',
#  'frame1428.jpg',
#  'frame1260.jpg',
#  'frame1824.jpg',
#  'frame1256.jpg',
#  'frame1388.jpg',
#  'frame1740.jpg',
#  'frame1736.jpg',
#  'frame1788.jpg',
#  'frame1756.jpg',
#  'frame1848.jpg',
#  'frame1236.jpg',
#  'frame1132.jpg',
#  'frame1636.jpg',
#  'frame1620.jpg',
#  'frame1624.jpg',
#  'frame1720.jpg',
#  'frame1184.jpg',
# ...

# %%
# !ls
# Out:
# custom_gun.zip	custom_weight  darknet	DATASET-ASFAR-gun-FRAME

# %%
#downloading and moving file to custom weight folder
# !wget https://pjreddie.com/media/files/darknet53.conv.74 custom_weight/
# Out:
# --2021-11-13 20:24:41--  https://pjreddie.com/media/files/darknet53.conv.74
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 162482580 (155M) [application/octet-stream]
# Saving to: ‘darknet53.conv.74’
#
# darknet53.conv.74   100%[===================>] 154.96M  20.0MB/s    in 9.0s
#
# 2021-11-13 20:24:51 (17.2 MB/s) - ‘darknet53.conv.74’ saved [162482580/162482580]
#
# --2021-11-13 20:24:51--  http://custom_weight/
# Resolving custom_weight (custom_weight)... failed: Name or service not known.
# wget: unable to resolve host address ‘custom_weight’
# FINISHED --2021-11-13 20:24:51--
# Total wall clock time: 9.8s
# Downloaded: 1 files, 155M in 9.0s (17.2 MB/s)

# %%
# !darknet/darknet
# Out:
# usage: darknet/darknet <function>

# %%
# !chmod +x darknet/darknet
#to give permission to darknet

# %%
# !darknet/darknet
# Out:
# usage: darknet/darknet <function>

# %%
# !darknet/darknet detector train DATASET-ASFAR-gun-FRAME/labelled_data.data darknet/cfg/yolov3_custom.cfg custom_weight/darknet53.conv.74
# Out:
# yolov3_custom
# layer     filters    size              input                output
#     0 conv     32  3 x 3 / 1   608 x 608 x   3   ->   608 x 608 x  32  0.639 BFLOPs
#     1 conv     64  3 x 3 / 2   608 x 608 x  32   ->   304 x 304 x  64  3.407 BFLOPs
#     2 conv     32  1 x 1 / 1   304 x 304 x  64   ->   304 x 304 x  32  0.379 BFLOPs
#     3 conv     64  3 x 3 / 1   304 x 304 x  32   ->   304 x 304 x  64  3.407 BFLOPs
#     4 res    1                 304 x 304 x  64   ->   304 x 304 x  64
#     5 conv    128  3 x 3 / 2   304 x 304 x  64   ->   152 x 152 x 128  3.407 BFLOPs
#     6 conv     64  1 x 1 / 1   152 x 152 x 128   ->   152 x 152 x  64  0.379 BFLOPs
#     7 conv    128  3 x 3 / 1   152 x 152 x  64   ->   152 x 152 x 128  3.407 BFLOPs
#     8 res    5                 152 x 152 x 128   ->   152 x 152 x 128
#     9 conv     64  1 x 1 / 1   152 x 152 x 128   ->   152 x 152 x  64  0.379 BFLOPs
# ...
